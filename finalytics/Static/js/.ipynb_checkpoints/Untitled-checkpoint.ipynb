# %%
import json
def load_stocks(file):
    #"""#reading company names from the text file containing list of available """
    stock_names=[]
    with open(file) as f:
        orgs = f.readlines()
    
    for i in range(len(orgs)):
        stock_names.append(orgs[i].rstrip('\n').split(','))
    stock = [item for sublist in stock_names for item in sublist]
    f.close()
    return stock

# %%
stocks = load_stocks('stocks.txt')

# %%
stocks
# Out:
# ['AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AADI',
#  'AAIC',
#  'AAIN',
#  'AAL',
#  'AAMC',
#  'AAME',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAQC',
#  'AAT',
#  'AATC',
#  'AAU',
#  'AAWW',
#  'AB',
#  'ABB',
#  'ABBV',
#  'ABC',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABEV',
#  'ABG',
#  'ABGI',
#  'ABIO',
#  'ABM',
#  'ABMD',
#  'ABNB',
#  'ABOS',
#  'ABR',
#  'ABSI',
#  'ABST',
#  'ABT',
#  'ABTX',
#  'ABUS',
#  'ABVC',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACB',
#  'ACBA',
#  'ACBAW',
#  'ACBI',
#  'ACC',
#  'ACCD',
#  'ACCO',
#  'ACEL',
#  'ACER',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACH',
#  'ACHC',
#  'ACHL',
#  'ACHR',
#  'ACHV',
#  'ACI',
#  'ACII',
#  'ACIU',
#  'ACIW',
#  'ACKIT',
#  'ACKIU',
#  'ACKIW',
#  'ACLS',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACOR',
#  'ACP',
#  'ACQR',
#  'ACQRU',
#  'ACQRW',
#  'ACR',
#  'ACRE',
#  'ACRO',
#  'ACRS',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTD',
#  'ACTDU',
#  'ACTDW',
#  'ACTG',
#  'ACU',
#  'ACV',
#  'ACVA',
#  'ACXP',
#  'ACY',
#  'ADAG',
#  'ADALU',
#  'ADAP',
#  'ADBE',
#  'ADC',
#  'ADCT',
#  'ADER',
#  'ADERW',
#  'ADES',
#  'ADEX',
#  'ADF',
#  'ADGI',
#  'ADI',
#  'ADIL',
#  'ADILW',
#  'ADM',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADNT',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
#  'ADRA',
#  'ADS',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADX',
#  'ADXN',
#  'ADXS',
#  'AE',
#  'AEAC',
#  'AEACU',
#  'AEACW',
#  'AEAEU',
#  'AEE',
#  'AEF',
#  'AEFC',
#  'AEG',
#  'AEHA',
#  'AEHAW',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEL',
#  'AEM',
#  'AEMD',
#  'AENZ',
#  'AEO',
#  'AEP',
#  'AEPPL',
#  'AEPPZ',
#  'AER',
#  'AERC',
#  'AERI',
#  'AES',
#  'AESC',
#  'AESE',
#  'AEVA',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFACU',
#  'AFAQ',
#  'AFAQU',
#  'AFAQW',
#  'AFB',
#  'AFBI',
#  'AFCG',
#  'AFG',
#  'AFGB',
#  'AFGC',
#  'AFGD',
#  'AFGE',
#  'AFI',
#  'AFIB',
#  'AFIN',
#  'AFINO',
#  'AFINP',
#  'AFL',
#  'AFMD',
#  'AFRM',
#  'AFT',
#  'AFTR',
#  'AFYA',
#  'AG',
#  'AGAC',
#  'AGBA',
#  'AGBAR',
#  'AGBAW',
#  'AGC',
#  'AGCB',
#  'AGCO',
#  'AGCUU',
#  'AGCWW',
#  'AGD',
#  'AGE',
#  'AGEN',
#  'AGFS',
#  'AGFY',
#  'AGGR',
#  'AGGRW',
#  'AGI',
#  'AGIL',
#  'AGILW',
#  'AGIO',
#  'AGL',
#  'AGLE',
#  'AGM',
#  'AGMH',
#  'AGNC',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGO',
#  'AGR',
#  'AGRI',
#  'AGRIW',
#  'AGRO',
#  'AGRX',
#  'AGS',
#  'AGTC',
#  'AGTI',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AHH',
#  'AHI',
#  'AHPAU',
#  'AHPAW',
#  'AHPI',
#  'AHT',
#  'AI',
#  'AIC',
#  'AIF',
#  'AIG',
#  'AIH',
#  'AIHS',
#  'AIKI',
#  'AIM',
#  'AIMC',
#  'AIN',
#  'AINC',
#  'AINV',
#  'AIO',
#  'AIP',
#  'AIR',
#  'AIRC',
#  'AIRG',
#  'AIRI',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AIT',
#  'AIV',
#  'AIZ',
#  'AIZN',
#  'AJG',
#  'AJRD',
#  'AJX',
#  'AJXA',
#  'AKA',
#  'AKAM',
#  'AKBA',
#  'AKIC',
#  'AKICU',
#  'AKICW',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKUS',
#  'AKYA',
#  'AL',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALACW',
#  'ALB',
#  'ALBO',
#  'ALC',
#  'ALCC',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALF',
#  'ALFIW',
#  'ALG',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALIT',
#  'ALJJ',
#  'ALK',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALLE',
#  'ALLK',
#  'ALLO',
#  'ALLT',
#  'ALLY',
#  'ALNA',
#  'ALNY',
#  'ALORU',
#  'ALOT',
#  'ALPA',
#  'ALPAW',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALSN',
#  'ALT',
#  'ALTG',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTU',
#  'ALTUU',
#  'ALTUW',
#  'ALV',
#  'ALVR',
#  'ALX',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AM',
#  'AMAL',
#  'AMAM',
#  'AMAO',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMBO',
#  'AMBP',
#  'AMC',
#  'AMCI',
#  'AMCIU',
#  'AMCIW',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMEH',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMK',
#  'AMKR',
#  'AMN',
#  'AMNB',
#  'AMOT',
#  'AMOV',
#  'AMP',
#  'AMPE',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPI',
#  'AMPL',
#  'AMPY',
#  'AMR',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMRX',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMT',
#  'AMTB',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMWL',
#  'AMX',
#  'AMYT',
#  'AMZN',
#  'AN',
#  'ANAB',
#  'ANAC',
#  'ANAT',
#  'ANDE',
#  'ANEB',
#  'ANET',
#  'ANF',
#  'ANGI',
#  'ANGN',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANPC',
#  'ANSS',
#  'ANTE',
#  'ANTM',
#  'ANVS',
#  'ANY',
#  'ANZU',
#  'ANZUU',
#  'ANZUW',
#  'AOD',
#  'AOMR',
#  'AON',
#  'AOS',
#  'AOSL',
#  'AOUT',
#  'AP',
#  'APA',
#  'APAC',
#  'APACU',
#  'APACW',
#  'APAM',
#  'APD',
#  'APDN',
#  'APEI',
#  'APEN',
#  'APG',
#  'APGB',
#  'APH',
#  'API',
#  'APLE',
#  'APLS',
#  'APLT',
#  'APM',
#  'APMI',
#  'APMIU',
#  'APMIW',
#  'APO',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPH',
#  'APPHW',
#  'APPN',
#  'APPS',
#  'APR',
#  'APRE',
#  'APRN',
#  'APSG',
#  'APT',
#  'APTM',
#  'APTMU',
#  'APTMW',
#  'APTO',
#  'APTS',
#  'APTV',
#  'APTX',
#  'APVO',
#  'APWC',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQN',
#  'AQNA',
#  'AQNB',
#  'AQNU',
#  'AQST',
#  'AQUA',
#  'AR',
#  'ARAV',
#  'ARAY',
#  'ARBE',
#  'ARBEW',
#  'ARBG',
#  'ARBGU',
#  'ARBK',
#  'ARBKL',
#  'ARC',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCH',
#  'ARCKU',
#  'ARCO',
#  'ARCT',
#  'ARDC',
#  'ARDS',
#  'ARDX',
#  'ARE',
#  'AREC',
#  'ARES',
#  'ARGD',
#  'ARGO',
#  'ARGU',
#  'ARGUU',
#  'ARGUW',
#  'ARGX',
#  'ARHS',
#  'ARI',
#  'ARIS',
#  'ARIZU',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARMK',
#  'ARMP',
#  'ARNA',
#  'ARNC',
#  'AROC',
#  'AROW',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARR',
#  'ARRW',
#  'ARRWU',
#  'ARRWW',
#  'ARRY',
#  'ARTA',
#  'ARTAU',
#  'ARTAW',
#  'ARTE',
#  'ARTEU',
#  'ARTEW',
#  'ARTL',
#  'ARTLW',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ARYD',
#  'ARYE',
#  'ASA',
#  'ASAI',
#  'ASAN',
#  'ASAQ',
#  'ASAX',
#  'ASAXU',
#  'ASAXW',
#  'ASB',
#  'ASC',
#  'ASG',
#  'ASGI',
#  'ASGN',
#  'ASH',
#  'ASIX',
#  'ASLE',
#  'ASLEW',
#  'ASLN',
#  'ASM',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPA',
#  'ASPAW',
#  'ASPC',
#  'ASPCU',
#  'ASPCW',
#  'ASPN',
#  'ASPS',
#  'ASPU',
#  'ASR',
#  'ASRT',
#  'ASRV',
#  'ASTC',
#  'ASTE',
#  'ASTL',
#  'ASTLW',
#  'ASTR',
#  'ASTRW',
#  'ASTS',
#  'ASTSW',
#  'ASUR',
#  'ASX',
#  'ASXC',
#  'ASYS',
#  'ASZ',
#  'ATA',
#  'ATAI',
#  'ATAQ',
#  'ATAX',
#  'ATC',
#  'ATCO',
#  'ATCOL',
#  'ATCX',
#  'ATEC',
#  'ATEN',
#  'ATER',
#  'ATEX',
#  'ATGE',
#  'ATH',
#  'ATHA',
#  'ATHE',
#  'ATHM',
#  'ATHN',
#  'ATHX',
#  'ATI',
#  'ATIF',
#  'ATIP',
#  'ATKR',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLO',
#  'ATMR',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNM',
#  'ATNX',
#  'ATO',
#  'ATOM',
#  'ATOS',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATRS',
#  'ATSG',
#  'ATSPT',
#  'ATSPU',
#  'ATSPW',
#  'ATTO',
#  'ATUS',
#  'ATVC',
#  'ATVCU',
#  'ATVCW',
#  'ATVI',
#  'ATXI',
#  'ATXS',
#  'ATY',
#  'AU',
#  'AUB',
#  'AUBAP',
#  'AUBN',
#  'AUD',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AUMN',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURC',
#  'AURCU',
#  'AURCW',
#  'AUROW',
#  'AUS',
#  'AUTL',
#  'AUTO',
#  'AUUD',
#  'AUUDW',
#  'AUVI',
#  'AUVIP',
#  'AUY',
#  'AVA',
#  'AVACU',
#  'AVAH',
#  'AVAL',
#  'AVAN',
#  'AVAV',
#  'AVB',
#  'AVCO',
#  'AVCT',
#  'AVCTW',
#  'AVD',
#  'AVDL',
#  'AVDX',
#  'AVEO',
#  'AVGO',
#  'AVGOP',
#  'AVGR',
#  'AVHI',
#  'AVHIU',
#  'AVHIW',
#  'AVID',
#  'AVIR',
#  'AVK',
#  'AVLR',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVRO',
#  'AVT',
#  'AVTE',
#  'AVTR',
#  'AVTX',
#  'AVXL',
#  'AVY',
#  'AVYA',
#  'AWF',
#  'AWH',
#  'AWI',
#  'AWK',
#  'AWP',
#  'AWR',
#  'AWRE',
#  'AWX',
#  'AX',
#  'AXDX',
#  'AXGN',
#  'AXL',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AXU',
#  'AY',
#  'AYI',
#  'AYLA',
#  'AYRO',
#  'AYTU',
#  'AYX',
#  'AZEK',
#  'AZN',
#  'AZO',
#  'AZPN',
#  'AZRE',
#  'AZUL',
#  'AZYO',
#  'AZZ',
#  'B',
#  'BA',
#  'BABA',
#  'BAC',
#  'BACA',
#  'BAH',
#  'BAK',
#  'BALY',
#  'BAM',
#  'BAMH',
#  'BAMI',
#  'BAMR',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BAP',
#  'BARK',
#  'BASE',
#  'BATL',
#  'BATRA',
#  'BATRK',
#  'BAX',
#  'BB',
#  'BBAR',
#  'BBBY',
#  'BBCP',
#  'BBD',
#  'BBDC',
#  'BBDO',
#  'BBGI',
#  'BBI',
#  'BBIG',
#  'BBIO',
#  'BBL',
#  'BBLG',
#  'BBLGW',
#  'BBLN',
#  'BBN',
#  'BBQ',
#  'BBSI',
#  'BBU',
#  'BBVA',
#  'BBW',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BCAB',
#  'BCAC',
#  'BCACU',
#  'BCACW',
#  'BCAT',
#  'BCBP',
#  'BCC',
#  'BCDA',
#  'BCDAW',
#  'BCE',
#  'BCEL',
#  'BCH',
#  'BCLI',
#  'BCML',
#  'BCO',
#  'BCOR',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCS',
#  'BCSAU',
#  'BCSF',
#  'BCTX',
#  'BCTXW',
#  'BCV',
#  'BCX',
#  'BCYC',
#  'BDC',
#  'BDJ',
#  'BDL',
#  'BDN',
#  'BDR',
#  'BDSI',
#  'BDSX',
#  'BDTX',
#  'BDX',
#  'BDXB',
#  'BE',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEDU',
#  'BEEM',
#  'BEEMW',
#  'BEKE',
#  'BELFA',
#  'BELFB',
#  'BEN',
#  'BENE',
#  'BENER',
#  'BENEU',
#  'BENEW',
#  'BEP',
#  'BEPC',
#  'BEPH',
#  'BERY',
#  'BEST',
#  'BFAM',
#  'BFC',
#  'BFI',
#  'BFIIW',
#  'BFIN',
#  'BFK',
#  'BFLY',
#  'BFRA',
#  'BFRI',
#  'BFRIW',
#  'BFS',
#  'BFST',
#  'BFZ',
#  'BG',
#  'BGB',
#  'BGCP',
#  'BGFV',
#  'BGH',
#  'BGI',
#  'BGIO',
#  'BGNE',
#  'BGR',
#  'BGRY',
#  'BGRYW',
#  'BGS',
#  'BGSF',
#  'BGT',
#  'BGX',
#  'BGY',
#  'BH',
#  'BHACU',
#  'BHAT',
#  'BHB',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHG',
#  'BHIL',
#  'BHK',
#  'BHLB',
#  'BHP',
#  'BHR',
#  'BHSE',
#  'BHSEW',
#  'BHTG',
#  'BHV',
#  'BHVN',
#  'BIDU',
#  'BIF',
#  'BIG',
#  'BIGC',
#  'BIGZ',
#  'BIIB',
#  'BILI',
#  'BILL',
#  'BIMI',
#  'BIO',
#  'BIO/B',
#  'BIOC',
#  'BIOL',
#  'BIOT',
#  'BIOTU',
#  'BIOTW',
#  'BIOX',
#  'BIP',
#  'BIPC',
#  'BIPH',
#  'BIRD',
#  'BIT',
#  'BITE',
#  'BITF',
#  'BIVI',
#  'BJ',
#  'BJDX',
#  'BJRI',
#  'BK',
#  'BKCC',
#  'BKD',
#  'BKE',
#  'BKEP',
#  'BKEPP',
#  'BKH',
#  'BKI',
#  'BKKT',
#  'BKN',
#  'BKNG',
#  'BKR',
#  'BKSC',
#  'BKSY',
#  'BKT',
#  'BKTI',
#  'BKU',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCM',
#  'BLCT',
#  'BLD',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLDR',
#  'BLE',
#  'BLEUU',
#  'BLFS',
#  'BLFY',
#  'BLI',
#  'BLIN',
#  'BLK',
#  'BLKB',
#  'BLL',
#  'BLMN',
#  'BLND',
#  'BLNG',
#  'BLNGW',
#  'BLNK',
#  'BLNKW',
#  'BLPH',
#  'BLRX',
#  'BLSA',
#  'BLTS',
#  'BLTSU',
#  'BLTSW',
#  'BLU',
#  'BLUA',
#  'BLUE',
#  'BLW',
#  'BLX',
#  'BLZE',
#  'BMA',
#  'BMAC',
#  ...]
